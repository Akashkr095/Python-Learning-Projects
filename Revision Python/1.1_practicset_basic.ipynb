# %% [markdown]
# 1. Write a program that prints:
#
# Hello, World! Welcome to Python.

# %%
print("Hello, World! Welcome to Python.")
# Out:
# Hello, World! Welcome to Python.

# %% [markdown]
# 2. Print a Poem
# Write a program that prints the following poem using a single print() statement:
#
#
# Twinkle, twinkle, little star,
#
# How I wonder what you are!

# %%
print("Twinkle, twinkle, little star,\nHow I wonder what you are!")
# Out:
# Twinkle, twinkle, little star,
# How I wonder what you are!

# %% [markdown]
# 3. Variables & Data Types
# Create variables to store:
#
# Your name (string)
#
# Your age (integer)
#
# Your height in meters (float)
#
# A boolean value representing whether you are a student
#
# Print all of them in one line.

# %%
name = "Akaash"
age = 20
height = 5.7
is_student = True

# 1st method - using f string
print(f"The name of student is {name}. He is {age} years old, {height} feet tall. Is he a student? {is_student}")

# 2nd method - using format function
print("The name of studemnt is " + name + ".He is " + str(age) + " years old, " + str(height) + " feet tall. Is he a student? " + str(is_student))
# Out:
# The name of student is Akaash. He is 20 years old, 5.7 feet tall. Is he a student? True
# The name of studemnt is Akaash.He is 20 years old, 5.7 feet tall. Is he a student? True

# %% [markdown]
# 4. Typecasting Practice
# You are given a string:
#
# num = "45"
#
# Convert it into an integer
# Add 10 to it
# Print the result

# %%
num = "45"
int_num = int(num) + 10
print(int_num)
# Out:
# 55

# %% [markdown]
# 5. Taking User Input
# Write a program that:
#
# Asks the user for their favorite food.
#
# Prints:
#
# Wow! I also like <food>.

# %%
fav_food  = input("Enter your favorite food: ")

print (f"Wow ! I also like {fav_food}.")
# Out:
# Wow ! I also like pizza.

# %% [markdown]
# 6. Simple Calculator
# Write a program that:
#
# Takes two numbers as input from the user.
#
# Prints their:
#
# Sum
# Difference
# Product
# Quotient

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

sum = a + b
print(f"The sum of {a} and {b} is {sum}.")

diff = a - b
print(f"The difference between {a} and {b} is {diff}.")

prod = a * b
print(f"The product of {a} and {b} is {prod}.")

quot = a / b
print(f"The quotient when {a} is divided by {b} is {quot}.")
# Out:
# The sum of 10 and 5 is 15.
# The difference between 10 and 5 is 5.
# The product of 10 and 5 is 50.
# The quotient when 10 is divided by 5 is 2.0.

# %% [markdown]
# 7.  Escape Sequences
# Print the following output using escape sequences:
#
# Hello "Python" World!
#
# This is on a new line.
#
# This is a tab →	    after tab.

# %%
print("Hello \"Python\" World!\nThis is on a new line.\nThis is a tab\tafter tab.")
# Out:
# Hello "Python" World!
# This is on a new line.
# This is a tab	after tab.

# %% [markdown]
# 8. Operator Challenge
# Write a program that:
#
# Takes an integer as input from the user.
#
# Prints the square and cube of that number.

# %%
num = int(input("Enter an number: "))

print("The square of the number is; ", num**2)
print("The cube of the number is; ", num**3)
# Out:
# The square of the number is;  4
# The cube of the number is;  8
