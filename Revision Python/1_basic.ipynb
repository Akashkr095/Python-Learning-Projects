# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print(3)
# Out:
# 3

# %%
age = 21
name = "akash"
cgpa = 9.1

# %%
print(age)
print(type(age))
print(name)
print(type(name))
print(cgpa)
print(type(cgpa))
# Out:
# 21
# <class 'int'>
# akash
# <class 'str'>
# 9.1
# <class 'float'>

# %%
is_student = True
print(is_student)
# Out:
# True

# %% [markdown]
# Type Casting

# %%
a = 5
b = "5"

print(a)
print(b)
# Out:
# 5
# 5

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# convert string to integer

c= int(b)
print(c)
print(type(c))
# Out:
# 5
# <class 'int'>

# %%
# converting integer to string

d = str(a)
print(d)
print(type(d))
# Out:
# 5
# <class 'str'>

# %%
x = 9
y = 4.5

print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
# convert integer to float
z = float(x)
print(z)
# Out:
# 9.0

# %%
# convert float to integer
w = int(y)
print(w)
print(type(w))
# Out:
# 4
# <class 'int'>

# %% [markdown]
# TAKING INPUT

# %%
name = input("Enter your name:")
age = int(input("Enter your age:"))
print(f"Hello {name}, your age is {age}") # f-string
# Out:
# Hello Akash, your age is 20

# %% [markdown]
# Escape sequences

# %%
print("HOW ARE YOU \nI AM FINE")
# Out:
# HOW ARE YOU
# I AM FINE

# %%
#escape sequences
print("This is a backslash: \\") # to print a backslash
print("He said, \"Hello!\"") # to print double quotes
print('It\'s a sunny day.') # to print single quote
print("Hello\tWorld") # tab space
print("Hello \" World") # double quotes within a string
# Out:
# This is a backslash: \
# He said, "Hello!"
# It's a sunny day.
# Hello	World
# Hello " World

# %% [markdown]
# operators in python

# %%
# arithmetic operators

a = 10
b = 3
print("Add:", a + b)
print("Sub:", a - b)
print("Multip:", a * b)
print("Div:", a / b)
print("Floor Div:", a // b)
print("Modulus:", a % b)
print("Exp:", a ** b)
# Out:
# Add: 13
# Sub: 7
# Multip: 30
# Div: 3.3333333333333335
# Floor Div: 3
# Modulus: 1
# Exp: 1000

# %%
# comparison operators

x = 5
y = 10
print("Equal:", x == y)
print("Not Equal:", x != y)
print("Greater than:", x > y)
print("Less than:", x < y)
print("Greater than or equal to:", x >= y)
print("Less than or equal to:", x <= y)
# Out:
# Equal: False
# Not Equal: True
# Greater than: False
# Less than: True
# Greater than or equal to: False
# Less than or equal to: True

# %%
# logical operators



# AND operator
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
# OR operator
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
# Not operator
print(not True)
print(not False)
# Out:
# False
# True

# %%
# ex logical operators
print(5>3  and 10>5)
print(5>3  or 10<5)
print(not(5>3))
# Out:
# True
# True
# False
